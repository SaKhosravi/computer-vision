# %%
#mount coloab
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab_Notebooks/akhavan_poor/deeplearning_class
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab_Notebooks/akhavan_poor/deeplearning_class

# %%
import tensorflow as tf 
import tensorflow_datasets as tfds
from tensorflow import keras
from keras.applications.vgg19 import VGG19,preprocess_input,decode_predictions
from keras.applications.mobilenet_v2 import MobileNetV2,preprocess_input,decode_predictions
from tf_data import TF_Dataa
import tensorflow_datasets as tfds
from keras import Model, Sequential
import os 
import zipfile

# %%
#downlaod  data from kaggle 
# ! pip install kaggle

# %%
# ! mkdir ~/.kaggle

# %%
# ! cp kaggle.json ~/.kaggle/

# %%
# ! chmod 600 ~/.kaggle/kaggle.json

# %%
# ! kaggle datasets download jangedoo/utkface-new

# %%
# with zipfile.ZipFile("utkface-new.zip", 'r') as zip_ref:
#     zip_ref.extractall(os.getcwd())

# %%
# !ls
# Out:
#  100img						    model.png
# 'age-gender detection using functional api.ipynb'   UTKFace
#  crop_part1					    utkface_aligned_cropped
#  model_checkpoints				    utkface-new.zip

# %%
data_dir = os.getcwd()+"/UTKFace"
data_dir
# Out:
# '/content/drive/MyDrive/Colab_Notebooks/akhavan_poor/deeplearning_class/UTKFace'

# %% [markdown]
# #### load train validation test data as tf data

# %%
mytfds = TF_Dataa(
    directory=data_dir, 
    validation_size=0.2,
    test_size = 0.2,
    batch_size = 64, 
    shuffle_buffer_size = 10000,
    augmentation = True , 
    shuffle_dataset = True , 
    input_target_size=[150,150,3]
)

# %%
train_dataset, validation_dataset, test_dataset =mytfds.train_validation_split()
# Out:
# ********* train_validation_split ***************
# ********* get_fullDataset ***************
# full datast size is: 23708
# train size: 14224, validation size:4743 , test size =4741
# ********* load_image_train ***************
# ********* load_image_with_label ***************
# ********* getTrainValidationData ***************  3
# ********* load_image_test ***************
# ********* load_image_with_label ***************
# ********* getTrainValidationData ***************  3
# ********* load_image_test ***************
# ********* load_image_with_label ***************
# ********* getTrainValidationData ***************  3

# %% [markdown]
# # load pre-trained model form keras application

# %%
#load model
base_model = MobileNetV2(weights="imagenet", include_top=False)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# 9420800/9406464 [==============================] - 0s 0us/step

# %%
base_model.trainable = True 
base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  Conv1 (Conv2D)                 (None, None, None,   864         ['input_1[0][0]']
#                                 32)
#
#  bn_Conv1 (BatchNormalization)  (None, None, None,   128         ['Conv1[0][0]']
#                                 32)
#
#  Conv1_relu (ReLU)              (None, None, None,   0           ['bn_Conv1[0][0]']
#                                 32)
#
#  expanded_conv_depthwise (Depth  (None, None, None,   288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    32)
#
#  expanded_conv_depthwise_BN (Ba  (None, None, None,   128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              32)
#
#  expanded_conv_depthwise_relu (  (None, None, None,   0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          32)                              ]']
#
#  expanded_conv_project (Conv2D)  (None, None, None,   512        ['expanded_conv_depthwise_relu[0]
#                                 16)                              [0]']
#
#  expanded_conv_project_BN (Batc  (None, None, None,   64         ['expanded_conv_project[0][0]']
#  hNormalization)                16)
#
#  block_1_expand (Conv2D)        (None, None, None,   1536        ['expanded_conv_project_BN[0][0]'
#                                 96)                              ]
#
#  block_1_expand_BN (BatchNormal  (None, None, None,   384        ['block_1_expand[0][0]']
#  ization)                       96)
#
#  block_1_expand_relu (ReLU)     (None, None, None,   0           ['block_1_expand_BN[0][0]']
#                                 96)
#
#  block_1_pad (ZeroPadding2D)    (None, None, None,   0           ['block_1_expand_relu[0][0]']
#                                 96)
#
#  block_1_depthwise (DepthwiseCo  (None, None, None,   864        ['block_1_pad[0][0]']
#  nv2D)                          96)
#
#  block_1_depthwise_BN (BatchNor  (None, None, None,   384        ['block_1_depthwise[0][0]']
#  malization)                    96)
#
#  block_1_depthwise_relu (ReLU)  (None, None, None,   0           ['block_1_depthwise_BN[0][0]']
#                                 96)
#
#  block_1_project (Conv2D)       (None, None, None,   2304        ['block_1_depthwise_relu[0][0]']
#                                 24)
#
#  block_1_project_BN (BatchNorma  (None, None, None,   96         ['block_1_project[0][0]']
#  lization)                      24)
#
#  block_2_expand (Conv2D)        (None, None, None,   3456        ['block_1_project_BN[0][0]']
#                                 144)
#
#  block_2_expand_BN (BatchNormal  (None, None, None,   576        ['block_2_expand[0][0]']
#  ization)                       144)
#
#  block_2_expand_relu (ReLU)     (None, None, None,   0           ['block_2_expand_BN[0][0]']
#                                 144)
#
#  block_2_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_2_expand_relu[0][0]']
#  nv2D)                          144)
#
#  block_2_depthwise_BN (BatchNor  (None, None, None,   576        ['block_2_depthwise[0][0]']
#  malization)                    144)
#
#  block_2_depthwise_relu (ReLU)  (None, None, None,   0           ['block_2_depthwise_BN[0][0]']
#                                 144)
#
#  block_2_project (Conv2D)       (None, None, None,   3456        ['block_2_depthwise_relu[0][0]']
#                                 24)
#
#  block_2_project_BN (BatchNorma  (None, None, None,   96         ['block_2_project[0][0]']
#  lization)                      24)
#
#  block_2_add (Add)              (None, None, None,   0           ['block_1_project_BN[0][0]',
#                                 24)                               'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, None, None,   3456        ['block_2_add[0][0]']
#                                 144)
#
#  block_3_expand_BN (BatchNormal  (None, None, None,   576        ['block_3_expand[0][0]']
#  ization)                       144)
#
#  block_3_expand_relu (ReLU)     (None, None, None,   0           ['block_3_expand_BN[0][0]']
#                                 144)
#
#  block_3_pad (ZeroPadding2D)    (None, None, None,   0           ['block_3_expand_relu[0][0]']
#                                 144)
#
#  block_3_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_3_pad[0][0]']
#  nv2D)                          144)
#
#  block_3_depthwise_BN (BatchNor  (None, None, None,   576        ['block_3_depthwise[0][0]']
#  malization)                    144)
#
#  block_3_depthwise_relu (ReLU)  (None, None, None,   0           ['block_3_depthwise_BN[0][0]']
#                                 144)
#
#  block_3_project (Conv2D)       (None, None, None,   4608        ['block_3_depthwise_relu[0][0]']
#                                 32)
#
#  block_3_project_BN (BatchNorma  (None, None, None,   128        ['block_3_project[0][0]']
#  lization)                      32)
#
#  block_4_expand (Conv2D)        (None, None, None,   6144        ['block_3_project_BN[0][0]']
#                                 192)
#
#  block_4_expand_BN (BatchNormal  (None, None, None,   768        ['block_4_expand[0][0]']
#  ization)                       192)
#
#  block_4_expand_relu (ReLU)     (None, None, None,   0           ['block_4_expand_BN[0][0]']
#                                 192)
#
#  block_4_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_4_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_4_depthwise_BN (BatchNor  (None, None, None,   768        ['block_4_depthwise[0][0]']
#  malization)                    192)
#
#  block_4_depthwise_relu (ReLU)  (None, None, None,   0           ['block_4_depthwise_BN[0][0]']
#                                 192)
#
#  block_4_project (Conv2D)       (None, None, None,   6144        ['block_4_depthwise_relu[0][0]']
#                                 32)
#
#  block_4_project_BN (BatchNorma  (None, None, None,   128        ['block_4_project[0][0]']
#  lization)                      32)
#
#  block_4_add (Add)              (None, None, None,   0           ['block_3_project_BN[0][0]',
#                                 32)                               'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, None, None,   6144        ['block_4_add[0][0]']
#                                 192)
#
#  block_5_expand_BN (BatchNormal  (None, None, None,   768        ['block_5_expand[0][0]']
#  ization)                       192)
#
#  block_5_expand_relu (ReLU)     (None, None, None,   0           ['block_5_expand_BN[0][0]']
#                                 192)
#
#  block_5_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_5_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_5_depthwise_BN (BatchNor  (None, None, None,   768        ['block_5_depthwise[0][0]']
#  malization)                    192)
#
#  block_5_depthwise_relu (ReLU)  (None, None, None,   0           ['block_5_depthwise_BN[0][0]']
#                                 192)
#
#  block_5_project (Conv2D)       (None, None, None,   6144        ['block_5_depthwise_relu[0][0]']
#                                 32)
#
#  block_5_project_BN (BatchNorma  (None, None, None,   128        ['block_5_project[0][0]']
#  lization)                      32)
#
#  block_5_add (Add)              (None, None, None,   0           ['block_4_add[0][0]',
#                                 32)                               'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, None, None,   6144        ['block_5_add[0][0]']
#                                 192)
#
#  block_6_expand_BN (BatchNormal  (None, None, None,   768        ['block_6_expand[0][0]']
#  ization)                       192)
#
#  block_6_expand_relu (ReLU)     (None, None, None,   0           ['block_6_expand_BN[0][0]']
#                                 192)
#
#  block_6_pad (ZeroPadding2D)    (None, None, None,   0           ['block_6_expand_relu[0][0]']
#                                 192)
#
#  block_6_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_6_pad[0][0]']
#  nv2D)                          192)
#
#  block_6_depthwise_BN (BatchNor  (None, None, None,   768        ['block_6_depthwise[0][0]']
#  malization)                    192)
#
#  block_6_depthwise_relu (ReLU)  (None, None, None,   0           ['block_6_depthwise_BN[0][0]']
#                                 192)
#
#  block_6_project (Conv2D)       (None, None, None,   12288       ['block_6_depthwise_relu[0][0]']
#                                 64)
#
#  block_6_project_BN (BatchNorma  (None, None, None,   256        ['block_6_project[0][0]']
#  lization)                      64)
#
#  block_7_expand (Conv2D)        (None, None, None,   24576       ['block_6_project_BN[0][0]']
#                                 384)
#
#  block_7_expand_BN (BatchNormal  (None, None, None,   1536       ['block_7_expand[0][0]']
#  ization)                       384)
#
#  block_7_expand_relu (ReLU)     (None, None, None,   0           ['block_7_expand_BN[0][0]']
#                                 384)
#
#  block_7_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_7_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_7_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_7_depthwise[0][0]']
#  malization)                    384)
#
#  block_7_depthwise_relu (ReLU)  (None, None, None,   0           ['block_7_depthwise_BN[0][0]']
#                                 384)
#
#  block_7_project (Conv2D)       (None, None, None,   24576       ['block_7_depthwise_relu[0][0]']
#                                 64)
#
#  block_7_project_BN (BatchNorma  (None, None, None,   256        ['block_7_project[0][0]']
#  lization)                      64)
#
#  block_7_add (Add)              (None, None, None,   0           ['block_6_project_BN[0][0]',
#                                 64)                               'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, None, None,   24576       ['block_7_add[0][0]']
#                                 384)
#
#  block_8_expand_BN (BatchNormal  (None, None, None,   1536       ['block_8_expand[0][0]']
#  ization)                       384)
#
#  block_8_expand_relu (ReLU)     (None, None, None,   0           ['block_8_expand_BN[0][0]']
#                                 384)
#
#  block_8_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_8_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_8_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_8_depthwise[0][0]']
#  malization)                    384)
#
#  block_8_depthwise_relu (ReLU)  (None, None, None,   0           ['block_8_depthwise_BN[0][0]']
#                                 384)
#
#  block_8_project (Conv2D)       (None, None, None,   24576       ['block_8_depthwise_relu[0][0]']
#                                 64)
#
#  block_8_project_BN (BatchNorma  (None, None, None,   256        ['block_8_project[0][0]']
#  lization)                      64)
#
#  block_8_add (Add)              (None, None, None,   0           ['block_7_add[0][0]',
#                                 64)                               'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, None, None,   24576       ['block_8_add[0][0]']
#                                 384)
#
#  block_9_expand_BN (BatchNormal  (None, None, None,   1536       ['block_9_expand[0][0]']
#  ization)                       384)
#
#  block_9_expand_relu (ReLU)     (None, None, None,   0           ['block_9_expand_BN[0][0]']
#                                 384)
#
#  block_9_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_9_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_9_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_9_depthwise[0][0]']
#  malization)                    384)
#
#  block_9_depthwise_relu (ReLU)  (None, None, None,   0           ['block_9_depthwise_BN[0][0]']
#                                 384)
#
#  block_9_project (Conv2D)       (None, None, None,   24576       ['block_9_depthwise_relu[0][0]']
#                                 64)
#
#  block_9_project_BN (BatchNorma  (None, None, None,   256        ['block_9_project[0][0]']
#  lization)                      64)
#
#  block_9_add (Add)              (None, None, None,   0           ['block_8_add[0][0]',
#                                 64)                               'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, None, None,   24576       ['block_9_add[0][0]']
#                                 384)
#
#  block_10_expand_BN (BatchNorma  (None, None, None,   1536       ['block_10_expand[0][0]']
#  lization)                      384)
#
#  block_10_expand_relu (ReLU)    (None, None, None,   0           ['block_10_expand_BN[0][0]']
#                                 384)
#
#  block_10_depthwise (DepthwiseC  (None, None, None,   3456       ['block_10_expand_relu[0][0]']
#  onv2D)                         384)
#
#  block_10_depthwise_BN (BatchNo  (None, None, None,   1536       ['block_10_depthwise[0][0]']
#  rmalization)                   384)
#
#  block_10_depthwise_relu (ReLU)  (None, None, None,   0          ['block_10_depthwise_BN[0][0]']
#                                 384)
#
#  block_10_project (Conv2D)      (None, None, None,   36864       ['block_10_depthwise_relu[0][0]']
#                                 96)
#
#  block_10_project_BN (BatchNorm  (None, None, None,   384        ['block_10_project[0][0]']
#  alization)                     96)
#
#  block_11_expand (Conv2D)       (None, None, None,   55296       ['block_10_project_BN[0][0]']
#                                 576)
#
#  block_11_expand_BN (BatchNorma  (None, None, None,   2304       ['block_11_expand[0][0]']
#  lization)                      576)
#
#  block_11_expand_relu (ReLU)    (None, None, None,   0           ['block_11_expand_BN[0][0]']
#                                 576)
#
#  block_11_depthwise (DepthwiseC  (None, None, None,   5184       ['block_11_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_11_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_11_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_11_depthwise_relu (ReLU)  (None, None, None,   0          ['block_11_depthwise_BN[0][0]']
#                                 576)
#
#  block_11_project (Conv2D)      (None, None, None,   55296       ['block_11_depthwise_relu[0][0]']
#                                 96)
#
#  block_11_project_BN (BatchNorm  (None, None, None,   384        ['block_11_project[0][0]']
#  alization)                     96)
#
#  block_11_add (Add)             (None, None, None,   0           ['block_10_project_BN[0][0]',
#                                 96)                               'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, None, None,   55296       ['block_11_add[0][0]']
#                                 576)
#
#  block_12_expand_BN (BatchNorma  (None, None, None,   2304       ['block_12_expand[0][0]']
#  lization)                      576)
#
#  block_12_expand_relu (ReLU)    (None, None, None,   0           ['block_12_expand_BN[0][0]']
#                                 576)
#
#  block_12_depthwise (DepthwiseC  (None, None, None,   5184       ['block_12_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_12_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_12_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_12_depthwise_relu (ReLU)  (None, None, None,   0          ['block_12_depthwise_BN[0][0]']
#                                 576)
#
#  block_12_project (Conv2D)      (None, None, None,   55296       ['block_12_depthwise_relu[0][0]']
#                                 96)
#
#  block_12_project_BN (BatchNorm  (None, None, None,   384        ['block_12_project[0][0]']
#  alization)                     96)
#
#  block_12_add (Add)             (None, None, None,   0           ['block_11_add[0][0]',
#                                 96)                               'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, None, None,   55296       ['block_12_add[0][0]']
#                                 576)
#
#  block_13_expand_BN (BatchNorma  (None, None, None,   2304       ['block_13_expand[0][0]']
#  lization)                      576)
#
#  block_13_expand_relu (ReLU)    (None, None, None,   0           ['block_13_expand_BN[0][0]']
#                                 576)
#
#  block_13_pad (ZeroPadding2D)   (None, None, None,   0           ['block_13_expand_relu[0][0]']
#                                 576)
#
#  block_13_depthwise (DepthwiseC  (None, None, None,   5184       ['block_13_pad[0][0]']
#  onv2D)                         576)
#
#  block_13_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_13_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_13_depthwise_relu (ReLU)  (None, None, None,   0          ['block_13_depthwise_BN[0][0]']
#                                 576)
#
#  block_13_project (Conv2D)      (None, None, None,   92160       ['block_13_depthwise_relu[0][0]']
#                                 160)
#
#  block_13_project_BN (BatchNorm  (None, None, None,   640        ['block_13_project[0][0]']
#  alization)                     160)
#
#  block_14_expand (Conv2D)       (None, None, None,   153600      ['block_13_project_BN[0][0]']
#                                 960)
#
#  block_14_expand_BN (BatchNorma  (None, None, None,   3840       ['block_14_expand[0][0]']
#  lization)                      960)
#
#  block_14_expand_relu (ReLU)    (None, None, None,   0           ['block_14_expand_BN[0][0]']
#                                 960)
#
#  block_14_depthwise (DepthwiseC  (None, None, None,   8640       ['block_14_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_14_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_14_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_14_depthwise_relu (ReLU)  (None, None, None,   0          ['block_14_depthwise_BN[0][0]']
#                                 960)
#
#  block_14_project (Conv2D)      (None, None, None,   153600      ['block_14_depthwise_relu[0][0]']
#                                 160)
#
#  block_14_project_BN (BatchNorm  (None, None, None,   640        ['block_14_project[0][0]']
#  alization)                     160)
#
#  block_14_add (Add)             (None, None, None,   0           ['block_13_project_BN[0][0]',
#                                 160)                              'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, None, None,   153600      ['block_14_add[0][0]']
#                                 960)
#
#  block_15_expand_BN (BatchNorma  (None, None, None,   3840       ['block_15_expand[0][0]']
#  lization)                      960)
#
#  block_15_expand_relu (ReLU)    (None, None, None,   0           ['block_15_expand_BN[0][0]']
#                                 960)
#
#  block_15_depthwise (DepthwiseC  (None, None, None,   8640       ['block_15_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_15_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_15_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_15_depthwise_relu (ReLU)  (None, None, None,   0          ['block_15_depthwise_BN[0][0]']
#                                 960)
#
#  block_15_project (Conv2D)      (None, None, None,   153600      ['block_15_depthwise_relu[0][0]']
#                                 160)
#
#  block_15_project_BN (BatchNorm  (None, None, None,   640        ['block_15_project[0][0]']
#  alization)                     160)
#
#  block_15_add (Add)             (None, None, None,   0           ['block_14_add[0][0]',
#                                 160)                              'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, None, None,   153600      ['block_15_add[0][0]']
#                                 960)
#
#  block_16_expand_BN (BatchNorma  (None, None, None,   3840       ['block_16_expand[0][0]']
#  lization)                      960)
#
#  block_16_expand_relu (ReLU)    (None, None, None,   0           ['block_16_expand_BN[0][0]']
#                                 960)
#
#  block_16_depthwise (DepthwiseC  (None, None, None,   8640       ['block_16_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_16_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_16_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_16_depthwise_relu (ReLU)  (None, None, None,   0          ['block_16_depthwise_BN[0][0]']
#                                 960)
#
#  block_16_project (Conv2D)      (None, None, None,   307200      ['block_16_depthwise_relu[0][0]']
#                                 320)
#
#  block_16_project_BN (BatchNorm  (None, None, None,   1280       ['block_16_project[0][0]']
#  alization)                     320)
#
#  Conv_1 (Conv2D)                (None, None, None,   409600      ['block_16_project_BN[0][0]']
#                                 1280)
#
#  Conv_1_bn (BatchNormalization)  (None, None, None,   5120       ['Conv_1[0][0]']
#                                 1280)
#
#  out_relu (ReLU)                (None, None, None,   0           ['Conv_1_bn[0][0]']
#                                 1280)
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 2,223,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________

# %%
for layer in base_model.layers:
  if "block_16" in layer.name:
    print(layer.name)
    layer.trainable = True
  else:
    layer.trainable = False
# Out:
# block_16_expand
# block_16_expand_BN
# block_16_expand_relu
# block_16_depthwise
# block_16_depthwise_BN
# block_16_depthwise_relu
# block_16_project
# block_16_project_BN

# %%
base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  Conv1 (Conv2D)                 (None, None, None,   864         ['input_1[0][0]']
#                                 32)
#
#  bn_Conv1 (BatchNormalization)  (None, None, None,   128         ['Conv1[0][0]']
#                                 32)
#
#  Conv1_relu (ReLU)              (None, None, None,   0           ['bn_Conv1[0][0]']
#                                 32)
#
#  expanded_conv_depthwise (Depth  (None, None, None,   288        ['Conv1_relu[0][0]']
#  wiseConv2D)                    32)
#
#  expanded_conv_depthwise_BN (Ba  (None, None, None,   128        ['expanded_conv_depthwise[0][0]']
#  tchNormalization)              32)
#
#  expanded_conv_depthwise_relu (  (None, None, None,   0          ['expanded_conv_depthwise_BN[0][0
#  ReLU)                          32)                              ]']
#
#  expanded_conv_project (Conv2D)  (None, None, None,   512        ['expanded_conv_depthwise_relu[0]
#                                 16)                              [0]']
#
#  expanded_conv_project_BN (Batc  (None, None, None,   64         ['expanded_conv_project[0][0]']
#  hNormalization)                16)
#
#  block_1_expand (Conv2D)        (None, None, None,   1536        ['expanded_conv_project_BN[0][0]'
#                                 96)                              ]
#
#  block_1_expand_BN (BatchNormal  (None, None, None,   384        ['block_1_expand[0][0]']
#  ization)                       96)
#
#  block_1_expand_relu (ReLU)     (None, None, None,   0           ['block_1_expand_BN[0][0]']
#                                 96)
#
#  block_1_pad (ZeroPadding2D)    (None, None, None,   0           ['block_1_expand_relu[0][0]']
#                                 96)
#
#  block_1_depthwise (DepthwiseCo  (None, None, None,   864        ['block_1_pad[0][0]']
#  nv2D)                          96)
#
#  block_1_depthwise_BN (BatchNor  (None, None, None,   384        ['block_1_depthwise[0][0]']
#  malization)                    96)
#
#  block_1_depthwise_relu (ReLU)  (None, None, None,   0           ['block_1_depthwise_BN[0][0]']
#                                 96)
#
#  block_1_project (Conv2D)       (None, None, None,   2304        ['block_1_depthwise_relu[0][0]']
#                                 24)
#
#  block_1_project_BN (BatchNorma  (None, None, None,   96         ['block_1_project[0][0]']
#  lization)                      24)
#
#  block_2_expand (Conv2D)        (None, None, None,   3456        ['block_1_project_BN[0][0]']
#                                 144)
#
#  block_2_expand_BN (BatchNormal  (None, None, None,   576        ['block_2_expand[0][0]']
#  ization)                       144)
#
#  block_2_expand_relu (ReLU)     (None, None, None,   0           ['block_2_expand_BN[0][0]']
#                                 144)
#
#  block_2_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_2_expand_relu[0][0]']
#  nv2D)                          144)
#
#  block_2_depthwise_BN (BatchNor  (None, None, None,   576        ['block_2_depthwise[0][0]']
#  malization)                    144)
#
#  block_2_depthwise_relu (ReLU)  (None, None, None,   0           ['block_2_depthwise_BN[0][0]']
#                                 144)
#
#  block_2_project (Conv2D)       (None, None, None,   3456        ['block_2_depthwise_relu[0][0]']
#                                 24)
#
#  block_2_project_BN (BatchNorma  (None, None, None,   96         ['block_2_project[0][0]']
#  lization)                      24)
#
#  block_2_add (Add)              (None, None, None,   0           ['block_1_project_BN[0][0]',
#                                 24)                               'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, None, None,   3456        ['block_2_add[0][0]']
#                                 144)
#
#  block_3_expand_BN (BatchNormal  (None, None, None,   576        ['block_3_expand[0][0]']
#  ization)                       144)
#
#  block_3_expand_relu (ReLU)     (None, None, None,   0           ['block_3_expand_BN[0][0]']
#                                 144)
#
#  block_3_pad (ZeroPadding2D)    (None, None, None,   0           ['block_3_expand_relu[0][0]']
#                                 144)
#
#  block_3_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_3_pad[0][0]']
#  nv2D)                          144)
#
#  block_3_depthwise_BN (BatchNor  (None, None, None,   576        ['block_3_depthwise[0][0]']
#  malization)                    144)
#
#  block_3_depthwise_relu (ReLU)  (None, None, None,   0           ['block_3_depthwise_BN[0][0]']
#                                 144)
#
#  block_3_project (Conv2D)       (None, None, None,   4608        ['block_3_depthwise_relu[0][0]']
#                                 32)
#
#  block_3_project_BN (BatchNorma  (None, None, None,   128        ['block_3_project[0][0]']
#  lization)                      32)
#
#  block_4_expand (Conv2D)        (None, None, None,   6144        ['block_3_project_BN[0][0]']
#                                 192)
#
#  block_4_expand_BN (BatchNormal  (None, None, None,   768        ['block_4_expand[0][0]']
#  ization)                       192)
#
#  block_4_expand_relu (ReLU)     (None, None, None,   0           ['block_4_expand_BN[0][0]']
#                                 192)
#
#  block_4_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_4_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_4_depthwise_BN (BatchNor  (None, None, None,   768        ['block_4_depthwise[0][0]']
#  malization)                    192)
#
#  block_4_depthwise_relu (ReLU)  (None, None, None,   0           ['block_4_depthwise_BN[0][0]']
#                                 192)
#
#  block_4_project (Conv2D)       (None, None, None,   6144        ['block_4_depthwise_relu[0][0]']
#                                 32)
#
#  block_4_project_BN (BatchNorma  (None, None, None,   128        ['block_4_project[0][0]']
#  lization)                      32)
#
#  block_4_add (Add)              (None, None, None,   0           ['block_3_project_BN[0][0]',
#                                 32)                               'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, None, None,   6144        ['block_4_add[0][0]']
#                                 192)
#
#  block_5_expand_BN (BatchNormal  (None, None, None,   768        ['block_5_expand[0][0]']
#  ization)                       192)
#
#  block_5_expand_relu (ReLU)     (None, None, None,   0           ['block_5_expand_BN[0][0]']
#                                 192)
#
#  block_5_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_5_expand_relu[0][0]']
#  nv2D)                          192)
#
#  block_5_depthwise_BN (BatchNor  (None, None, None,   768        ['block_5_depthwise[0][0]']
#  malization)                    192)
#
#  block_5_depthwise_relu (ReLU)  (None, None, None,   0           ['block_5_depthwise_BN[0][0]']
#                                 192)
#
#  block_5_project (Conv2D)       (None, None, None,   6144        ['block_5_depthwise_relu[0][0]']
#                                 32)
#
#  block_5_project_BN (BatchNorma  (None, None, None,   128        ['block_5_project[0][0]']
#  lization)                      32)
#
#  block_5_add (Add)              (None, None, None,   0           ['block_4_add[0][0]',
#                                 32)                               'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, None, None,   6144        ['block_5_add[0][0]']
#                                 192)
#
#  block_6_expand_BN (BatchNormal  (None, None, None,   768        ['block_6_expand[0][0]']
#  ization)                       192)
#
#  block_6_expand_relu (ReLU)     (None, None, None,   0           ['block_6_expand_BN[0][0]']
#                                 192)
#
#  block_6_pad (ZeroPadding2D)    (None, None, None,   0           ['block_6_expand_relu[0][0]']
#                                 192)
#
#  block_6_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_6_pad[0][0]']
#  nv2D)                          192)
#
#  block_6_depthwise_BN (BatchNor  (None, None, None,   768        ['block_6_depthwise[0][0]']
#  malization)                    192)
#
#  block_6_depthwise_relu (ReLU)  (None, None, None,   0           ['block_6_depthwise_BN[0][0]']
#                                 192)
#
#  block_6_project (Conv2D)       (None, None, None,   12288       ['block_6_depthwise_relu[0][0]']
#                                 64)
#
#  block_6_project_BN (BatchNorma  (None, None, None,   256        ['block_6_project[0][0]']
#  lization)                      64)
#
#  block_7_expand (Conv2D)        (None, None, None,   24576       ['block_6_project_BN[0][0]']
#                                 384)
#
#  block_7_expand_BN (BatchNormal  (None, None, None,   1536       ['block_7_expand[0][0]']
#  ization)                       384)
#
#  block_7_expand_relu (ReLU)     (None, None, None,   0           ['block_7_expand_BN[0][0]']
#                                 384)
#
#  block_7_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_7_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_7_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_7_depthwise[0][0]']
#  malization)                    384)
#
#  block_7_depthwise_relu (ReLU)  (None, None, None,   0           ['block_7_depthwise_BN[0][0]']
#                                 384)
#
#  block_7_project (Conv2D)       (None, None, None,   24576       ['block_7_depthwise_relu[0][0]']
#                                 64)
#
#  block_7_project_BN (BatchNorma  (None, None, None,   256        ['block_7_project[0][0]']
#  lization)                      64)
#
#  block_7_add (Add)              (None, None, None,   0           ['block_6_project_BN[0][0]',
#                                 64)                               'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, None, None,   24576       ['block_7_add[0][0]']
#                                 384)
#
#  block_8_expand_BN (BatchNormal  (None, None, None,   1536       ['block_8_expand[0][0]']
#  ization)                       384)
#
#  block_8_expand_relu (ReLU)     (None, None, None,   0           ['block_8_expand_BN[0][0]']
#                                 384)
#
#  block_8_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_8_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_8_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_8_depthwise[0][0]']
#  malization)                    384)
#
#  block_8_depthwise_relu (ReLU)  (None, None, None,   0           ['block_8_depthwise_BN[0][0]']
#                                 384)
#
#  block_8_project (Conv2D)       (None, None, None,   24576       ['block_8_depthwise_relu[0][0]']
#                                 64)
#
#  block_8_project_BN (BatchNorma  (None, None, None,   256        ['block_8_project[0][0]']
#  lization)                      64)
#
#  block_8_add (Add)              (None, None, None,   0           ['block_7_add[0][0]',
#                                 64)                               'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, None, None,   24576       ['block_8_add[0][0]']
#                                 384)
#
#  block_9_expand_BN (BatchNormal  (None, None, None,   1536       ['block_9_expand[0][0]']
#  ization)                       384)
#
#  block_9_expand_relu (ReLU)     (None, None, None,   0           ['block_9_expand_BN[0][0]']
#                                 384)
#
#  block_9_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_9_expand_relu[0][0]']
#  nv2D)                          384)
#
#  block_9_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_9_depthwise[0][0]']
#  malization)                    384)
#
#  block_9_depthwise_relu (ReLU)  (None, None, None,   0           ['block_9_depthwise_BN[0][0]']
#                                 384)
#
#  block_9_project (Conv2D)       (None, None, None,   24576       ['block_9_depthwise_relu[0][0]']
#                                 64)
#
#  block_9_project_BN (BatchNorma  (None, None, None,   256        ['block_9_project[0][0]']
#  lization)                      64)
#
#  block_9_add (Add)              (None, None, None,   0           ['block_8_add[0][0]',
#                                 64)                               'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, None, None,   24576       ['block_9_add[0][0]']
#                                 384)
#
#  block_10_expand_BN (BatchNorma  (None, None, None,   1536       ['block_10_expand[0][0]']
#  lization)                      384)
#
#  block_10_expand_relu (ReLU)    (None, None, None,   0           ['block_10_expand_BN[0][0]']
#                                 384)
#
#  block_10_depthwise (DepthwiseC  (None, None, None,   3456       ['block_10_expand_relu[0][0]']
#  onv2D)                         384)
#
#  block_10_depthwise_BN (BatchNo  (None, None, None,   1536       ['block_10_depthwise[0][0]']
#  rmalization)                   384)
#
#  block_10_depthwise_relu (ReLU)  (None, None, None,   0          ['block_10_depthwise_BN[0][0]']
#                                 384)
#
#  block_10_project (Conv2D)      (None, None, None,   36864       ['block_10_depthwise_relu[0][0]']
#                                 96)
#
#  block_10_project_BN (BatchNorm  (None, None, None,   384        ['block_10_project[0][0]']
#  alization)                     96)
#
#  block_11_expand (Conv2D)       (None, None, None,   55296       ['block_10_project_BN[0][0]']
#                                 576)
#
#  block_11_expand_BN (BatchNorma  (None, None, None,   2304       ['block_11_expand[0][0]']
#  lization)                      576)
#
#  block_11_expand_relu (ReLU)    (None, None, None,   0           ['block_11_expand_BN[0][0]']
#                                 576)
#
#  block_11_depthwise (DepthwiseC  (None, None, None,   5184       ['block_11_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_11_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_11_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_11_depthwise_relu (ReLU)  (None, None, None,   0          ['block_11_depthwise_BN[0][0]']
#                                 576)
#
#  block_11_project (Conv2D)      (None, None, None,   55296       ['block_11_depthwise_relu[0][0]']
#                                 96)
#
#  block_11_project_BN (BatchNorm  (None, None, None,   384        ['block_11_project[0][0]']
#  alization)                     96)
#
#  block_11_add (Add)             (None, None, None,   0           ['block_10_project_BN[0][0]',
#                                 96)                               'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, None, None,   55296       ['block_11_add[0][0]']
#                                 576)
#
#  block_12_expand_BN (BatchNorma  (None, None, None,   2304       ['block_12_expand[0][0]']
#  lization)                      576)
#
#  block_12_expand_relu (ReLU)    (None, None, None,   0           ['block_12_expand_BN[0][0]']
#                                 576)
#
#  block_12_depthwise (DepthwiseC  (None, None, None,   5184       ['block_12_expand_relu[0][0]']
#  onv2D)                         576)
#
#  block_12_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_12_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_12_depthwise_relu (ReLU)  (None, None, None,   0          ['block_12_depthwise_BN[0][0]']
#                                 576)
#
#  block_12_project (Conv2D)      (None, None, None,   55296       ['block_12_depthwise_relu[0][0]']
#                                 96)
#
#  block_12_project_BN (BatchNorm  (None, None, None,   384        ['block_12_project[0][0]']
#  alization)                     96)
#
#  block_12_add (Add)             (None, None, None,   0           ['block_11_add[0][0]',
#                                 96)                               'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, None, None,   55296       ['block_12_add[0][0]']
#                                 576)
#
#  block_13_expand_BN (BatchNorma  (None, None, None,   2304       ['block_13_expand[0][0]']
#  lization)                      576)
#
#  block_13_expand_relu (ReLU)    (None, None, None,   0           ['block_13_expand_BN[0][0]']
#                                 576)
#
#  block_13_pad (ZeroPadding2D)   (None, None, None,   0           ['block_13_expand_relu[0][0]']
#                                 576)
#
#  block_13_depthwise (DepthwiseC  (None, None, None,   5184       ['block_13_pad[0][0]']
#  onv2D)                         576)
#
#  block_13_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_13_depthwise[0][0]']
#  rmalization)                   576)
#
#  block_13_depthwise_relu (ReLU)  (None, None, None,   0          ['block_13_depthwise_BN[0][0]']
#                                 576)
#
#  block_13_project (Conv2D)      (None, None, None,   92160       ['block_13_depthwise_relu[0][0]']
#                                 160)
#
#  block_13_project_BN (BatchNorm  (None, None, None,   640        ['block_13_project[0][0]']
#  alization)                     160)
#
#  block_14_expand (Conv2D)       (None, None, None,   153600      ['block_13_project_BN[0][0]']
#                                 960)
#
#  block_14_expand_BN (BatchNorma  (None, None, None,   3840       ['block_14_expand[0][0]']
#  lization)                      960)
#
#  block_14_expand_relu (ReLU)    (None, None, None,   0           ['block_14_expand_BN[0][0]']
#                                 960)
#
#  block_14_depthwise (DepthwiseC  (None, None, None,   8640       ['block_14_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_14_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_14_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_14_depthwise_relu (ReLU)  (None, None, None,   0          ['block_14_depthwise_BN[0][0]']
#                                 960)
#
#  block_14_project (Conv2D)      (None, None, None,   153600      ['block_14_depthwise_relu[0][0]']
#                                 160)
#
#  block_14_project_BN (BatchNorm  (None, None, None,   640        ['block_14_project[0][0]']
#  alization)                     160)
#
#  block_14_add (Add)             (None, None, None,   0           ['block_13_project_BN[0][0]',
#                                 160)                              'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, None, None,   153600      ['block_14_add[0][0]']
#                                 960)
#
#  block_15_expand_BN (BatchNorma  (None, None, None,   3840       ['block_15_expand[0][0]']
#  lization)                      960)
#
#  block_15_expand_relu (ReLU)    (None, None, None,   0           ['block_15_expand_BN[0][0]']
#                                 960)
#
#  block_15_depthwise (DepthwiseC  (None, None, None,   8640       ['block_15_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_15_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_15_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_15_depthwise_relu (ReLU)  (None, None, None,   0          ['block_15_depthwise_BN[0][0]']
#                                 960)
#
#  block_15_project (Conv2D)      (None, None, None,   153600      ['block_15_depthwise_relu[0][0]']
#                                 160)
#
#  block_15_project_BN (BatchNorm  (None, None, None,   640        ['block_15_project[0][0]']
#  alization)                     160)
#
#  block_15_add (Add)             (None, None, None,   0           ['block_14_add[0][0]',
#                                 160)                              'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, None, None,   153600      ['block_15_add[0][0]']
#                                 960)
#
#  block_16_expand_BN (BatchNorma  (None, None, None,   3840       ['block_16_expand[0][0]']
#  lization)                      960)
#
#  block_16_expand_relu (ReLU)    (None, None, None,   0           ['block_16_expand_BN[0][0]']
#                                 960)
#
#  block_16_depthwise (DepthwiseC  (None, None, None,   8640       ['block_16_expand_relu[0][0]']
#  onv2D)                         960)
#
#  block_16_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_16_depthwise[0][0]']
#  rmalization)                   960)
#
#  block_16_depthwise_relu (ReLU)  (None, None, None,   0          ['block_16_depthwise_BN[0][0]']
#                                 960)
#
#  block_16_project (Conv2D)      (None, None, None,   307200      ['block_16_depthwise_relu[0][0]']
#                                 320)
#
#  block_16_project_BN (BatchNorm  (None, None, None,   1280       ['block_16_project[0][0]']
#  alization)                     320)
#
#  Conv_1 (Conv2D)                (None, None, None,   409600      ['block_16_project_BN[0][0]']
#                                 1280)
#
#  Conv_1_bn (BatchNormalization)  (None, None, None,   5120       ['Conv_1[0][0]']
#                                 1280)
#
#  out_relu (ReLU)                (None, None, None,   0           ['Conv_1_bn[0][0]']
#                                 1280)
#
# ==================================================================================================
# Total params: 2,257,984
# Trainable params: 473,920
# Non-trainable params: 1,784,064
# __________________________________________________________________________________________________

# %%
base_model.output_shape
# Out:
# (None, None, None, 1280)

# %%
# > CONV/FC -> BatchNorm -> ReLu(or other activation) -> Dropout -
x = keras.layers.GlobalAveragePooling2D()(base_model.output)
age = tf.keras.layers.Dense(256,
                    kernel_regularizer=tf.keras.regularizers.L1(0.01),
                     activity_regularizer=tf.keras.regularizers.L2(0.01)
                            )(x)
age = tf.keras.layers.BatchNormalization()(age)
age = tf.keras.layers.LeakyReLU(alpha= 0.1)(age)
age  = tf.keras.layers.Dropout(0.5)(age)


age = keras.layers.Dense(128,
                         kernel_regularizer=tf.keras.regularizers.L1(0.01),
                     activity_regularizer=tf.keras.regularizers.L2(0.01)
                         )(age)
age = keras.layers.BatchNormalization()(age)
age = keras.layers.LeakyReLU(alpha=0.1)(age)
age = keras.layers.Dropout(rate = 0.4)(age)

age = keras.layers.Dense(32,
                         kernel_regularizer=tf.keras.regularizers.L1(0.01),
                     activity_regularizer=tf.keras.regularizers.L2(0.01)
                         )(age)
age = keras.layers.BatchNormalization()(age)
age = keras.layers.LeakyReLU(alpha=0.1)(age)
age = keras.layers.Dropout(rate = 0.4)(age)

age = keras.layers.Dense(8,
                         kernel_regularizer=tf.keras.regularizers.L1(0.01),
                     activity_regularizer=tf.keras.regularizers.L2(0.01)
                         )(age)
age = keras.layers.BatchNormalization()(age)
age = keras.layers.LeakyReLU(alpha=0.1)(age)
age = keras.layers.Dropout(rate = 0.4)(age)

age = keras.layers.Dense(4,
                         kernel_regularizer=tf.keras.regularizers.L1(0.01),
                     activity_regularizer=tf.keras.regularizers.L2(0.01)
                         )(age)
age = keras.layers.BatchNormalization()(age)
age = keras.layers.LeakyReLU(alpha=0.1)(age)
age = keras.layers.Dropout(rate = 0.4)(age)


age = keras.layers.Dense(1, activation="linear" , name="age")(age)




gender = keras.layers.Dense(256,
                    kernel_regularizer=tf.keras.regularizers.L1(0.01),
                     activity_regularizer=tf.keras.regularizers.L2(0.01))(x)
                     
gender = keras.layers.BatchNormalization()(gender)
gender = keras.layers.LeakyReLU(alpha=0.1)(gender)
gender = keras.layers.Dropout(rate = 0.4)(gender)


gender = keras.layers.Dense(128,
                    kernel_regularizer=tf.keras.regularizers.L1(0.01),
                     activity_regularizer=tf.keras.regularizers.L2(0.01))(x)
                     
gender = keras.layers.BatchNormalization()(gender)
gender = keras.layers.LeakyReLU(alpha=0.1)(gender)
gender = keras.layers.Dropout(rate = 0.4)(gender)



gender = keras.layers.Dense(32,
                     kernel_regularizer=tf.keras.regularizers.L1(0.01),
                     activity_regularizer=tf.keras.regularizers.L2(0.01)
                            )(gender)
gender = keras.layers.BatchNormalization()(gender)
gender = keras.layers.LeakyReLU(alpha=0.1)(gender)
gender = keras.layers.Dropout(rate = 0.4)(gender)


gender = keras.layers.Dense(16, 
                            kernel_regularizer=tf.keras.regularizers.L1(0.01),
                     activity_regularizer=tf.keras.regularizers.L2(0.01)
                            )(gender)
gender = keras.layers.BatchNormalization()(gender)
gender = keras.layers.LeakyReLU(alpha=0.1)(gender)
gender = keras.layers.Dropout(rate = 0.3)(gender)

gender = keras.layers.Dense(8, 
                            kernel_regularizer=tf.keras.regularizers.L1(0.01),
                     activity_regularizer=tf.keras.regularizers.L2(0.01)
                            )(gender)
gender = keras.layers.BatchNormalization()(gender)
gender = keras.layers.LeakyReLU(alpha=0.1)(gender)
gender = keras.layers.Dropout(rate = 0.3)(gender)


gender = keras.layers.Dense(4, 
                            kernel_regularizer=tf.keras.regularizers.L1(0.01),
                     activity_regularizer=tf.keras.regularizers.L2(0.01)
                            )(gender)
gender = keras.layers.BatchNormalization()(gender)
gender = keras.layers.LeakyReLU(alpha=0.1)(gender)
gender = keras.layers.Dropout(rate = 0.3)(gender)

gender = keras.layers.Dense(1, activation="sigmoid",name="gender")(gender)


model = keras.Model(
    inputs=base_model.input, 
    outputs= [gender,age]
)

# %%
keras.utils.plot_model(model,show_shapes=True)

# %%
model.summary(show_trainable = True)
# Out:
# Model: "model_1"
# _____________________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to                     Trainable
# =============================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []                               N
#                                  3)]
#
#  Conv1 (Conv2D)                 (None, None, None,   864         ['input_1[0][0]']                N
#                                 32)
#
#  bn_Conv1 (BatchNormalization)  (None, None, None,   128         ['Conv1[0][0]']                  N
#                                 32)
#
#  Conv1_relu (ReLU)              (None, None, None,   0           ['bn_Conv1[0][0]']               N
#                                 32)
#
#  expanded_conv_depthwise (Depth  (None, None, None,   288        ['Conv1_relu[0][0]']             N
#  wiseConv2D)                    32)
#
#  expanded_conv_depthwise_BN (Ba  (None, None, None,   128        ['expanded_conv_depthwise[0][0]  N
#  tchNormalization)              32)                              ']
#
#  expanded_conv_depthwise_relu (  (None, None, None,   0          ['expanded_conv_depthwise_BN[0]  N
#  ReLU)                          32)                              [0]']
#
#  expanded_conv_project (Conv2D)  (None, None, None,   512        ['expanded_conv_depthwise_relu[  N
#                                 16)                              0][0]']
#
#  expanded_conv_project_BN (Batc  (None, None, None,   64         ['expanded_conv_project[0][0]']  N
#  hNormalization)                16)
#
#  block_1_expand (Conv2D)        (None, None, None,   1536        ['expanded_conv_project_BN[0][0  N
#                                 96)                              ]']
#
#  block_1_expand_BN (BatchNormal  (None, None, None,   384        ['block_1_expand[0][0]']         N
#  ization)                       96)
#
#  block_1_expand_relu (ReLU)     (None, None, None,   0           ['block_1_expand_BN[0][0]']      N
#                                 96)
#
#  block_1_pad (ZeroPadding2D)    (None, None, None,   0           ['block_1_expand_relu[0][0]']    N
#                                 96)
#
#  block_1_depthwise (DepthwiseCo  (None, None, None,   864        ['block_1_pad[0][0]']            N
#  nv2D)                          96)
#
#  block_1_depthwise_BN (BatchNor  (None, None, None,   384        ['block_1_depthwise[0][0]']      N
#  malization)                    96)
#
#  block_1_depthwise_relu (ReLU)  (None, None, None,   0           ['block_1_depthwise_BN[0][0]']   N
#                                 96)
#
#  block_1_project (Conv2D)       (None, None, None,   2304        ['block_1_depthwise_relu[0][0]'  N
#                                 24)                              ]
#
#  block_1_project_BN (BatchNorma  (None, None, None,   96         ['block_1_project[0][0]']        N
#  lization)                      24)
#
#  block_2_expand (Conv2D)        (None, None, None,   3456        ['block_1_project_BN[0][0]']     N
#                                 144)
#
#  block_2_expand_BN (BatchNormal  (None, None, None,   576        ['block_2_expand[0][0]']         N
#  ization)                       144)
#
#  block_2_expand_relu (ReLU)     (None, None, None,   0           ['block_2_expand_BN[0][0]']      N
#                                 144)
#
#  block_2_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_2_expand_relu[0][0]']    N
#  nv2D)                          144)
#
#  block_2_depthwise_BN (BatchNor  (None, None, None,   576        ['block_2_depthwise[0][0]']      N
#  malization)                    144)
#
#  block_2_depthwise_relu (ReLU)  (None, None, None,   0           ['block_2_depthwise_BN[0][0]']   N
#                                 144)
#
#  block_2_project (Conv2D)       (None, None, None,   3456        ['block_2_depthwise_relu[0][0]'  N
#                                 24)                              ]
#
#  block_2_project_BN (BatchNorma  (None, None, None,   96         ['block_2_project[0][0]']        N
#  lization)                      24)
#
#  block_2_add (Add)              (None, None, None,   0           ['block_1_project_BN[0][0]',     N
#                                 24)                               'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)        (None, None, None,   3456        ['block_2_add[0][0]']            N
#                                 144)
#
#  block_3_expand_BN (BatchNormal  (None, None, None,   576        ['block_3_expand[0][0]']         N
#  ization)                       144)
#
#  block_3_expand_relu (ReLU)     (None, None, None,   0           ['block_3_expand_BN[0][0]']      N
#                                 144)
#
#  block_3_pad (ZeroPadding2D)    (None, None, None,   0           ['block_3_expand_relu[0][0]']    N
#                                 144)
#
#  block_3_depthwise (DepthwiseCo  (None, None, None,   1296       ['block_3_pad[0][0]']            N
#  nv2D)                          144)
#
#  block_3_depthwise_BN (BatchNor  (None, None, None,   576        ['block_3_depthwise[0][0]']      N
#  malization)                    144)
#
#  block_3_depthwise_relu (ReLU)  (None, None, None,   0           ['block_3_depthwise_BN[0][0]']   N
#                                 144)
#
#  block_3_project (Conv2D)       (None, None, None,   4608        ['block_3_depthwise_relu[0][0]'  N
#                                 32)                              ]
#
#  block_3_project_BN (BatchNorma  (None, None, None,   128        ['block_3_project[0][0]']        N
#  lization)                      32)
#
#  block_4_expand (Conv2D)        (None, None, None,   6144        ['block_3_project_BN[0][0]']     N
#                                 192)
#
#  block_4_expand_BN (BatchNormal  (None, None, None,   768        ['block_4_expand[0][0]']         N
#  ization)                       192)
#
#  block_4_expand_relu (ReLU)     (None, None, None,   0           ['block_4_expand_BN[0][0]']      N
#                                 192)
#
#  block_4_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_4_expand_relu[0][0]']    N
#  nv2D)                          192)
#
#  block_4_depthwise_BN (BatchNor  (None, None, None,   768        ['block_4_depthwise[0][0]']      N
#  malization)                    192)
#
#  block_4_depthwise_relu (ReLU)  (None, None, None,   0           ['block_4_depthwise_BN[0][0]']   N
#                                 192)
#
#  block_4_project (Conv2D)       (None, None, None,   6144        ['block_4_depthwise_relu[0][0]'  N
#                                 32)                              ]
#
#  block_4_project_BN (BatchNorma  (None, None, None,   128        ['block_4_project[0][0]']        N
#  lization)                      32)
#
#  block_4_add (Add)              (None, None, None,   0           ['block_3_project_BN[0][0]',     N
#                                 32)                               'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)        (None, None, None,   6144        ['block_4_add[0][0]']            N
#                                 192)
#
#  block_5_expand_BN (BatchNormal  (None, None, None,   768        ['block_5_expand[0][0]']         N
#  ization)                       192)
#
#  block_5_expand_relu (ReLU)     (None, None, None,   0           ['block_5_expand_BN[0][0]']      N
#                                 192)
#
#  block_5_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_5_expand_relu[0][0]']    N
#  nv2D)                          192)
#
#  block_5_depthwise_BN (BatchNor  (None, None, None,   768        ['block_5_depthwise[0][0]']      N
#  malization)                    192)
#
#  block_5_depthwise_relu (ReLU)  (None, None, None,   0           ['block_5_depthwise_BN[0][0]']   N
#                                 192)
#
#  block_5_project (Conv2D)       (None, None, None,   6144        ['block_5_depthwise_relu[0][0]'  N
#                                 32)                              ]
#
#  block_5_project_BN (BatchNorma  (None, None, None,   128        ['block_5_project[0][0]']        N
#  lization)                      32)
#
#  block_5_add (Add)              (None, None, None,   0           ['block_4_add[0][0]',            N
#                                 32)                               'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)        (None, None, None,   6144        ['block_5_add[0][0]']            N
#                                 192)
#
#  block_6_expand_BN (BatchNormal  (None, None, None,   768        ['block_6_expand[0][0]']         N
#  ization)                       192)
#
#  block_6_expand_relu (ReLU)     (None, None, None,   0           ['block_6_expand_BN[0][0]']      N
#                                 192)
#
#  block_6_pad (ZeroPadding2D)    (None, None, None,   0           ['block_6_expand_relu[0][0]']    N
#                                 192)
#
#  block_6_depthwise (DepthwiseCo  (None, None, None,   1728       ['block_6_pad[0][0]']            N
#  nv2D)                          192)
#
#  block_6_depthwise_BN (BatchNor  (None, None, None,   768        ['block_6_depthwise[0][0]']      N
#  malization)                    192)
#
#  block_6_depthwise_relu (ReLU)  (None, None, None,   0           ['block_6_depthwise_BN[0][0]']   N
#                                 192)
#
#  block_6_project (Conv2D)       (None, None, None,   12288       ['block_6_depthwise_relu[0][0]'  N
#                                 64)                              ]
#
#  block_6_project_BN (BatchNorma  (None, None, None,   256        ['block_6_project[0][0]']        N
#  lization)                      64)
#
#  block_7_expand (Conv2D)        (None, None, None,   24576       ['block_6_project_BN[0][0]']     N
#                                 384)
#
#  block_7_expand_BN (BatchNormal  (None, None, None,   1536       ['block_7_expand[0][0]']         N
#  ization)                       384)
#
#  block_7_expand_relu (ReLU)     (None, None, None,   0           ['block_7_expand_BN[0][0]']      N
#                                 384)
#
#  block_7_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_7_expand_relu[0][0]']    N
#  nv2D)                          384)
#
#  block_7_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_7_depthwise[0][0]']      N
#  malization)                    384)
#
#  block_7_depthwise_relu (ReLU)  (None, None, None,   0           ['block_7_depthwise_BN[0][0]']   N
#                                 384)
#
#  block_7_project (Conv2D)       (None, None, None,   24576       ['block_7_depthwise_relu[0][0]'  N
#                                 64)                              ]
#
#  block_7_project_BN (BatchNorma  (None, None, None,   256        ['block_7_project[0][0]']        N
#  lization)                      64)
#
#  block_7_add (Add)              (None, None, None,   0           ['block_6_project_BN[0][0]',     N
#                                 64)                               'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)        (None, None, None,   24576       ['block_7_add[0][0]']            N
#                                 384)
#
#  block_8_expand_BN (BatchNormal  (None, None, None,   1536       ['block_8_expand[0][0]']         N
#  ization)                       384)
#
#  block_8_expand_relu (ReLU)     (None, None, None,   0           ['block_8_expand_BN[0][0]']      N
#                                 384)
#
#  block_8_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_8_expand_relu[0][0]']    N
#  nv2D)                          384)
#
#  block_8_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_8_depthwise[0][0]']      N
#  malization)                    384)
#
#  block_8_depthwise_relu (ReLU)  (None, None, None,   0           ['block_8_depthwise_BN[0][0]']   N
#                                 384)
#
#  block_8_project (Conv2D)       (None, None, None,   24576       ['block_8_depthwise_relu[0][0]'  N
#                                 64)                              ]
#
#  block_8_project_BN (BatchNorma  (None, None, None,   256        ['block_8_project[0][0]']        N
#  lization)                      64)
#
#  block_8_add (Add)              (None, None, None,   0           ['block_7_add[0][0]',            N
#                                 64)                               'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)        (None, None, None,   24576       ['block_8_add[0][0]']            N
#                                 384)
#
#  block_9_expand_BN (BatchNormal  (None, None, None,   1536       ['block_9_expand[0][0]']         N
#  ization)                       384)
#
#  block_9_expand_relu (ReLU)     (None, None, None,   0           ['block_9_expand_BN[0][0]']      N
#                                 384)
#
#  block_9_depthwise (DepthwiseCo  (None, None, None,   3456       ['block_9_expand_relu[0][0]']    N
#  nv2D)                          384)
#
#  block_9_depthwise_BN (BatchNor  (None, None, None,   1536       ['block_9_depthwise[0][0]']      N
#  malization)                    384)
#
#  block_9_depthwise_relu (ReLU)  (None, None, None,   0           ['block_9_depthwise_BN[0][0]']   N
#                                 384)
#
#  block_9_project (Conv2D)       (None, None, None,   24576       ['block_9_depthwise_relu[0][0]'  N
#                                 64)                              ]
#
#  block_9_project_BN (BatchNorma  (None, None, None,   256        ['block_9_project[0][0]']        N
#  lization)                      64)
#
#  block_9_add (Add)              (None, None, None,   0           ['block_8_add[0][0]',            N
#                                 64)                               'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)       (None, None, None,   24576       ['block_9_add[0][0]']            N
#                                 384)
#
#  block_10_expand_BN (BatchNorma  (None, None, None,   1536       ['block_10_expand[0][0]']        N
#  lization)                      384)
#
#  block_10_expand_relu (ReLU)    (None, None, None,   0           ['block_10_expand_BN[0][0]']     N
#                                 384)
#
#  block_10_depthwise (DepthwiseC  (None, None, None,   3456       ['block_10_expand_relu[0][0]']   N
#  onv2D)                         384)
#
#  block_10_depthwise_BN (BatchNo  (None, None, None,   1536       ['block_10_depthwise[0][0]']     N
#  rmalization)                   384)
#
#  block_10_depthwise_relu (ReLU)  (None, None, None,   0          ['block_10_depthwise_BN[0][0]']  N
#                                 384)
#
#  block_10_project (Conv2D)      (None, None, None,   36864       ['block_10_depthwise_relu[0][0]  N
#                                 96)                              ']
#
#  block_10_project_BN (BatchNorm  (None, None, None,   384        ['block_10_project[0][0]']       N
#  alization)                     96)
#
#  block_11_expand (Conv2D)       (None, None, None,   55296       ['block_10_project_BN[0][0]']    N
#                                 576)
#
#  block_11_expand_BN (BatchNorma  (None, None, None,   2304       ['block_11_expand[0][0]']        N
#  lization)                      576)
#
#  block_11_expand_relu (ReLU)    (None, None, None,   0           ['block_11_expand_BN[0][0]']     N
#                                 576)
#
#  block_11_depthwise (DepthwiseC  (None, None, None,   5184       ['block_11_expand_relu[0][0]']   N
#  onv2D)                         576)
#
#  block_11_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_11_depthwise[0][0]']     N
#  rmalization)                   576)
#
#  block_11_depthwise_relu (ReLU)  (None, None, None,   0          ['block_11_depthwise_BN[0][0]']  N
#                                 576)
#
#  block_11_project (Conv2D)      (None, None, None,   55296       ['block_11_depthwise_relu[0][0]  N
#                                 96)                              ']
#
#  block_11_project_BN (BatchNorm  (None, None, None,   384        ['block_11_project[0][0]']       N
#  alization)                     96)
#
#  block_11_add (Add)             (None, None, None,   0           ['block_10_project_BN[0][0]',    N
#                                 96)                               'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)       (None, None, None,   55296       ['block_11_add[0][0]']           N
#                                 576)
#
#  block_12_expand_BN (BatchNorma  (None, None, None,   2304       ['block_12_expand[0][0]']        N
#  lization)                      576)
#
#  block_12_expand_relu (ReLU)    (None, None, None,   0           ['block_12_expand_BN[0][0]']     N
#                                 576)
#
#  block_12_depthwise (DepthwiseC  (None, None, None,   5184       ['block_12_expand_relu[0][0]']   N
#  onv2D)                         576)
#
#  block_12_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_12_depthwise[0][0]']     N
#  rmalization)                   576)
#
#  block_12_depthwise_relu (ReLU)  (None, None, None,   0          ['block_12_depthwise_BN[0][0]']  N
#                                 576)
#
#  block_12_project (Conv2D)      (None, None, None,   55296       ['block_12_depthwise_relu[0][0]  N
#                                 96)                              ']
#
#  block_12_project_BN (BatchNorm  (None, None, None,   384        ['block_12_project[0][0]']       N
#  alization)                     96)
#
#  block_12_add (Add)             (None, None, None,   0           ['block_11_add[0][0]',           N
#                                 96)                               'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)       (None, None, None,   55296       ['block_12_add[0][0]']           N
#                                 576)
#
#  block_13_expand_BN (BatchNorma  (None, None, None,   2304       ['block_13_expand[0][0]']        N
#  lization)                      576)
#
#  block_13_expand_relu (ReLU)    (None, None, None,   0           ['block_13_expand_BN[0][0]']     N
#                                 576)
#
#  block_13_pad (ZeroPadding2D)   (None, None, None,   0           ['block_13_expand_relu[0][0]']   N
#                                 576)
#
#  block_13_depthwise (DepthwiseC  (None, None, None,   5184       ['block_13_pad[0][0]']           N
#  onv2D)                         576)
#
#  block_13_depthwise_BN (BatchNo  (None, None, None,   2304       ['block_13_depthwise[0][0]']     N
#  rmalization)                   576)
#
#  block_13_depthwise_relu (ReLU)  (None, None, None,   0          ['block_13_depthwise_BN[0][0]']  N
#                                 576)
#
#  block_13_project (Conv2D)      (None, None, None,   92160       ['block_13_depthwise_relu[0][0]  N
#                                 160)                             ']
#
#  block_13_project_BN (BatchNorm  (None, None, None,   640        ['block_13_project[0][0]']       N
#  alization)                     160)
#
#  block_14_expand (Conv2D)       (None, None, None,   153600      ['block_13_project_BN[0][0]']    N
#                                 960)
#
#  block_14_expand_BN (BatchNorma  (None, None, None,   3840       ['block_14_expand[0][0]']        N
#  lization)                      960)
#
#  block_14_expand_relu (ReLU)    (None, None, None,   0           ['block_14_expand_BN[0][0]']     N
#                                 960)
#
#  block_14_depthwise (DepthwiseC  (None, None, None,   8640       ['block_14_expand_relu[0][0]']   N
#  onv2D)                         960)
#
#  block_14_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_14_depthwise[0][0]']     N
#  rmalization)                   960)
#
#  block_14_depthwise_relu (ReLU)  (None, None, None,   0          ['block_14_depthwise_BN[0][0]']  N
#                                 960)
#
#  block_14_project (Conv2D)      (None, None, None,   153600      ['block_14_depthwise_relu[0][0]  N
#                                 160)                             ']
#
#  block_14_project_BN (BatchNorm  (None, None, None,   640        ['block_14_project[0][0]']       N
#  alization)                     160)
#
#  block_14_add (Add)             (None, None, None,   0           ['block_13_project_BN[0][0]',    N
#                                 160)                              'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)       (None, None, None,   153600      ['block_14_add[0][0]']           N
#                                 960)
#
#  block_15_expand_BN (BatchNorma  (None, None, None,   3840       ['block_15_expand[0][0]']        N
#  lization)                      960)
#
#  block_15_expand_relu (ReLU)    (None, None, None,   0           ['block_15_expand_BN[0][0]']     N
#                                 960)
#
#  block_15_depthwise (DepthwiseC  (None, None, None,   8640       ['block_15_expand_relu[0][0]']   N
#  onv2D)                         960)
#
#  block_15_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_15_depthwise[0][0]']     N
#  rmalization)                   960)
#
#  block_15_depthwise_relu (ReLU)  (None, None, None,   0          ['block_15_depthwise_BN[0][0]']  N
#                                 960)
#
#  block_15_project (Conv2D)      (None, None, None,   153600      ['block_15_depthwise_relu[0][0]  N
#                                 160)                             ']
#
#  block_15_project_BN (BatchNorm  (None, None, None,   640        ['block_15_project[0][0]']       N
#  alization)                     160)
#
#  block_15_add (Add)             (None, None, None,   0           ['block_14_add[0][0]',           N
#                                 160)                              'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)       (None, None, None,   153600      ['block_15_add[0][0]']           Y
#                                 960)
#
#  block_16_expand_BN (BatchNorma  (None, None, None,   3840       ['block_16_expand[0][0]']        Y
#  lization)                      960)
#
#  block_16_expand_relu (ReLU)    (None, None, None,   0           ['block_16_expand_BN[0][0]']     Y
#                                 960)
#
#  block_16_depthwise (DepthwiseC  (None, None, None,   8640       ['block_16_expand_relu[0][0]']   Y
#  onv2D)                         960)
#
#  block_16_depthwise_BN (BatchNo  (None, None, None,   3840       ['block_16_depthwise[0][0]']     Y
#  rmalization)                   960)
#
#  block_16_depthwise_relu (ReLU)  (None, None, None,   0          ['block_16_depthwise_BN[0][0]']  Y
#                                 960)
#
#  block_16_project (Conv2D)      (None, None, None,   307200      ['block_16_depthwise_relu[0][0]  Y
#                                 320)                             ']
#
#  block_16_project_BN (BatchNorm  (None, None, None,   1280       ['block_16_project[0][0]']       Y
#  alization)                     320)
#
#  Conv_1 (Conv2D)                (None, None, None,   409600      ['block_16_project_BN[0][0]']    N
#                                 1280)
#
#  Conv_1_bn (BatchNormalization)  (None, None, None,   5120       ['Conv_1[0][0]']                 N
#                                 1280)
#
#  out_relu (ReLU)                (None, None, None,   0           ['Conv_1_bn[0][0]']              N
#                                 1280)
#
#  global_average_pooling2d_1 (Gl  (None, 1280)        0           ['out_relu[0][0]']               Y
#  obalAveragePooling2D)
#
#  dense_17 (Dense)               (None, 128)          163968      ['global_average_pooling2d_1[0]  Y
#                                                                  [0]']
#
#  dense_11 (Dense)               (None, 256)          327936      ['global_average_pooling2d_1[0]  Y
#                                                                  [0]']
#
#  batch_normalization_17 (BatchN  (None, 128)         512         ['dense_17[0][0]']               Y
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 256)         1024        ['dense_11[0][0]']               Y
#  ormalization)
#
#  leaky_re_lu_17 (LeakyReLU)     (None, 128)          0           ['batch_normalization_17[0][0]'  Y
#                                                                  ]
#
#  leaky_re_lu_11 (LeakyReLU)     (None, 256)          0           ['batch_normalization_11[0][0]'  Y
#                                                                  ]
#
#  dropout_17 (Dropout)           (None, 128)          0           ['leaky_re_lu_17[0][0]']         Y
#
#  dropout_11 (Dropout)           (None, 256)          0           ['leaky_re_lu_11[0][0]']         Y
#
#  dense_18 (Dense)               (None, 32)           4128        ['dropout_17[0][0]']             Y
#
#  dense_12 (Dense)               (None, 128)          32896       ['dropout_11[0][0]']             Y
#
#  batch_normalization_18 (BatchN  (None, 32)          128         ['dense_18[0][0]']               Y
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 128)         512         ['dense_12[0][0]']               Y
#  ormalization)
#
#  leaky_re_lu_18 (LeakyReLU)     (None, 32)           0           ['batch_normalization_18[0][0]'  Y
#                                                                  ]
#
#  leaky_re_lu_12 (LeakyReLU)     (None, 128)          0           ['batch_normalization_12[0][0]'  Y
#                                                                  ]
#
#  dropout_18 (Dropout)           (None, 32)           0           ['leaky_re_lu_18[0][0]']         Y
#
#  dropout_12 (Dropout)           (None, 128)          0           ['leaky_re_lu_12[0][0]']         Y
#
#  dense_19 (Dense)               (None, 16)           528         ['dropout_18[0][0]']             Y
#
#  dense_13 (Dense)               (None, 32)           4128        ['dropout_12[0][0]']             Y
#
#  batch_normalization_19 (BatchN  (None, 16)          64          ['dense_19[0][0]']               Y
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 32)          128         ['dense_13[0][0]']               Y
#  ormalization)
#
#  leaky_re_lu_19 (LeakyReLU)     (None, 16)           0           ['batch_normalization_19[0][0]'  Y
#                                                                  ]
#
#  leaky_re_lu_13 (LeakyReLU)     (None, 32)           0           ['batch_normalization_13[0][0]'  Y
#                                                                  ]
#
#  dropout_19 (Dropout)           (None, 16)           0           ['leaky_re_lu_19[0][0]']         Y
#
#  dropout_13 (Dropout)           (None, 32)           0           ['leaky_re_lu_13[0][0]']         Y
#
#  dense_20 (Dense)               (None, 8)            136         ['dropout_19[0][0]']             Y
#
#  dense_14 (Dense)               (None, 8)            264         ['dropout_13[0][0]']             Y
#
#  batch_normalization_20 (BatchN  (None, 8)           32          ['dense_20[0][0]']               Y
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 8)           32          ['dense_14[0][0]']               Y
#  ormalization)
#
#  leaky_re_lu_20 (LeakyReLU)     (None, 8)            0           ['batch_normalization_20[0][0]'  Y
#                                                                  ]
#
#  leaky_re_lu_14 (LeakyReLU)     (None, 8)            0           ['batch_normalization_14[0][0]'  Y
#                                                                  ]
#
#  dropout_20 (Dropout)           (None, 8)            0           ['leaky_re_lu_20[0][0]']         Y
#
#  dropout_14 (Dropout)           (None, 8)            0           ['leaky_re_lu_14[0][0]']         Y
#
#  dense_21 (Dense)               (None, 4)            36          ['dropout_20[0][0]']             Y
#
#  dense_15 (Dense)               (None, 4)            36          ['dropout_14[0][0]']             Y
#
#  batch_normalization_21 (BatchN  (None, 4)           16          ['dense_21[0][0]']               Y
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 4)           16          ['dense_15[0][0]']               Y
#  ormalization)
#
#  leaky_re_lu_21 (LeakyReLU)     (None, 4)            0           ['batch_normalization_21[0][0]'  Y
#                                                                  ]
#
#  leaky_re_lu_15 (LeakyReLU)     (None, 4)            0           ['batch_normalization_15[0][0]'  Y
#                                                                  ]
#
#  dropout_21 (Dropout)           (None, 4)            0           ['leaky_re_lu_21[0][0]']         Y
#
#  dropout_15 (Dropout)           (None, 4)            0           ['leaky_re_lu_15[0][0]']         Y
#
#  gender (Dense)                 (None, 1)            5           ['dropout_21[0][0]']             Y
#
#  age (Dense)                    (None, 1)            5           ['dropout_15[0][0]']             Y
#
# =============================================================================================================
# Total params: 2,794,514
# Trainable params: 1,009,218
# Non-trainable params: 1,785,296
# _____________________________________________________________________________________________________________

# %%
keras.utils.plot_model(model,show_shapes=True)

# %%
losses = {
    "age": "mean_absolute_percentage_error",
    "gender": "binary_crossentropy"
    # "ethnicity" : "sparse_categorical_crossentropy"
}
loss_weights = {
    "age": 1.0,
    "gender": 1.0
    
    }

_metrics = {'age':'mse',
           'gender':"accuracy"}

          #  ,'ethnicity':tf.keras.metrics.Accuracy(name='accuracy', dtype=None)}

# %%
model.output
# Out:
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'gender')>,
#  <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'age')>]

# %%
          
model.compile(
    optimizer = "adam",
    loss=losses,
              # loss_weights=loss_weights,
              # metrics ={'gender': 'accuracy','age':'mse'}
              metrics = _metrics
              )

# %%
from keras.callbacks import EarlyStopping,ModelCheckpoint,ReduceLROnPlateau,LearningRateScheduler

# %%
def lr_decay(epoch, lr):
    if epoch != 0 and epoch % 5 == 0:
        return lr * 0.2
    return lr

# %%
custom_early_stopping = EarlyStopping(
    monitor='val_accuracy', 
    patience=3, 
    min_delta=0.001, 
    mode='max'
)

checkpoint_path = 'model_checkpoints/'
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,
    save_freq='epoch',
    save_weights_only=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.2,   
    patience=2, 
    min_lr=0.001,
    verbose=2
)
_callbacks = [
            #  LearningRateScheduler(lr_decay, verbose=1),
             custom_early_stopping,
             reduce_lr,
             checkpoint
             ]

# %%
hist = model.fit(
    train_dataset,
    validation_data = validation_dataset, 


    epochs = 30,
    batch_size = 32,
     callbacks =_callbacks   
)
# Out:
# Epoch 1/30
# 223/223 [==============================] - ETA: 0s - loss: 164.0783 - gender_loss: 0.6597 - age_loss: 91.2927 - gender_accuracy: 0.6283 - age_mse: 1415.2152WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 1: saving model to model_checkpoints/
# 223/223 [==============================] - 1148s 2s/step - loss: 164.0783 - gender_loss: 0.6597 - age_loss: 91.2927 - gender_accuracy: 0.6283 - age_mse: 1415.2152 - val_loss: 172.2694 - val_gender_loss: 0.6831 - val_age_loss: 75.5782 - val_gender_accuracy: 0.5170 - val_age_mse: 1075.9147 - lr: 0.0010
# Epoch 2/30
# 223/223 [==============================] - ETA: 0s - loss: 136.5208 - gender_loss: 0.6280 - age_loss: 89.4873 - gender_accuracy: 0.6501 - age_mse: 1403.8844WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 2: saving model to model_checkpoints/
# 223/223 [==============================] - 554s 1s/step - loss: 136.5208 - gender_loss: 0.6280 - age_loss: 89.4873 - gender_accuracy: 0.6501 - age_mse: 1403.8844 - val_loss: 148.3100 - val_gender_loss: 0.6851 - val_age_loss: 88.0946 - val_gender_accuracy: 0.5195 - val_age_mse: 1266.5188 - lr: 0.0010
# Epoch 3/30
# 223/223 [==============================] - ETA: 0s - loss: 121.3616 - gender_loss: 0.5873 - age_loss: 86.9022 - gender_accuracy: 0.6879 - age_mse: 1356.0917WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 3: saving model to model_checkpoints/
# 223/223 [==============================] - 393s 1s/step - loss: 121.3616 - gender_loss: 0.5873 - age_loss: 86.9022 - gender_accuracy: 0.6879 - age_mse: 1356.0917 - val_loss: 122.3929 - val_gender_loss: 0.6289 - val_age_loss: 85.3743 - val_gender_accuracy: 0.6011 - val_age_mse: 1296.2817 - lr: 0.0010
# Epoch 4/30
# 223/223 [==============================] - ETA: 0s - loss: 112.8136 - gender_loss: 0.5516 - age_loss: 84.1836 - gender_accuracy: 0.7298 - age_mse: 1315.2321WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 4: saving model to model_checkpoints/
# 223/223 [==============================] - 361s 1s/step - loss: 112.8136 - gender_loss: 0.5516 - age_loss: 84.1836 - gender_accuracy: 0.7298 - age_mse: 1315.2321 - val_loss: 100.5788 - val_gender_loss: 0.5792 - val_age_loss: 72.6046 - val_gender_accuracy: 0.7645 - val_age_mse: 1185.9424 - lr: 0.0010
# Epoch 5/30
# 223/223 [==============================] - ETA: 0s - loss: 105.0992 - gender_loss: 0.5292 - age_loss: 80.8338 - gender_accuracy: 0.7497 - age_mse: 1269.0350WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 5: saving model to model_checkpoints/
# 223/223 [==============================] - 337s 1s/step - loss: 105.0992 - gender_loss: 0.5292 - age_loss: 80.8338 - gender_accuracy: 0.7497 - age_mse: 1269.0350 - val_loss: 105.9050 - val_gender_loss: 0.4751 - val_age_loss: 79.7855 - val_gender_accuracy: 0.7921 - val_age_mse: 1257.4487 - lr: 0.0010
# Epoch 6/30
# 223/223 [==============================] - ETA: 0s - loss: 103.2306 - gender_loss: 0.5532 - age_loss: 77.1319 - gender_accuracy: 0.7298 - age_mse: 1220.4082WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 6: saving model to model_checkpoints/
# 223/223 [==============================] - 331s 1s/step - loss: 103.2306 - gender_loss: 0.5532 - age_loss: 77.1319 - gender_accuracy: 0.7298 - age_mse: 1220.4082 - val_loss: 93.9764 - val_gender_loss: 0.8551 - val_age_loss: 71.4448 - val_gender_accuracy: 0.5672 - val_age_mse: 1132.0120 - lr: 0.0010
# Epoch 7/30
# 223/223 [==============================] - ETA: 0s - loss: 92.8156 - gender_loss: 0.5355 - age_loss: 72.5181 - gender_accuracy: 0.7532 - age_mse: 1145.0073WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 7: saving model to model_checkpoints/
# 223/223 [==============================] - 331s 1s/step - loss: 92.8156 - gender_loss: 0.5355 - age_loss: 72.5181 - gender_accuracy: 0.7532 - age_mse: 1145.0073 - val_loss: 88.6181 - val_gender_loss: 0.4622 - val_age_loss: 67.9190 - val_gender_accuracy: 0.7925 - val_age_mse: 1038.1154 - lr: 0.0010
# Epoch 8/30
# 223/223 [==============================] - ETA: 0s - loss: 86.7445 - gender_loss: 0.5248 - age_loss: 68.2808 - gender_accuracy: 0.7567 - age_mse: 1065.6959WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 8: saving model to model_checkpoints/
# 223/223 [==============================] - 329s 1s/step - loss: 86.7445 - gender_loss: 0.5248 - age_loss: 68.2808 - gender_accuracy: 0.7567 - age_mse: 1065.6959 - val_loss: 82.5813 - val_gender_loss: 0.5687 - val_age_loss: 65.1093 - val_gender_accuracy: 0.6947 - val_age_mse: 963.2769 - lr: 0.0010
# Epoch 9/30
# 223/223 [==============================] - ETA: 0s - loss: 82.8577 - gender_loss: 0.5177 - age_loss: 65.2556 - gender_accuracy: 0.7614 - age_mse: 987.3552WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 9: saving model to model_checkpoints/
# 223/223 [==============================] - 323s 1s/step - loss: 82.8577 - gender_loss: 0.5177 - age_loss: 65.2556 - gender_accuracy: 0.7614 - age_mse: 987.3552 - val_loss: 89.9079 - val_gender_loss: 0.4766 - val_age_loss: 72.7500 - val_gender_accuracy: 0.7708 - val_age_mse: 1118.0599 - lr: 0.0010
# Epoch 10/30
# 223/223 [==============================] - ETA: 0s - loss: 79.5480 - gender_loss: 0.5094 - age_loss: 62.2926 - gender_accuracy: 0.7604 - age_mse: 909.2759WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 10: saving model to model_checkpoints/
# 223/223 [==============================] - 318s 1s/step - loss: 79.5480 - gender_loss: 0.5094 - age_loss: 62.2926 - gender_accuracy: 0.7604 - age_mse: 909.2759 - val_loss: 76.0840 - val_gender_loss: 0.6840 - val_age_loss: 56.3244 - val_gender_accuracy: 0.5891 - val_age_mse: 866.7983 - lr: 0.0010
# Epoch 11/30
# 223/223 [==============================] - ETA: 0s - loss: 75.2856 - gender_loss: 0.5082 - age_loss: 59.8613 - gender_accuracy: 0.7605 - age_mse: 821.8035WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 11: saving model to model_checkpoints/
# 223/223 [==============================] - 321s 1s/step - loss: 75.2856 - gender_loss: 0.5082 - age_loss: 59.8613 - gender_accuracy: 0.7605 - age_mse: 821.8035 - val_loss: 64.9021 - val_gender_loss: 0.4622 - val_age_loss: 49.8124 - val_gender_accuracy: 0.7843 - val_age_mse: 613.4272 - lr: 0.0010
# Epoch 12/30
# 223/223 [==============================] - ETA: 0s - loss: 72.8846 - gender_loss: 0.5078 - age_loss: 57.9828 - gender_accuracy: 0.7662 - age_mse: 771.1946WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 12: saving model to model_checkpoints/
# 223/223 [==============================] - 327s 1s/step - loss: 72.8846 - gender_loss: 0.5078 - age_loss: 57.9828 - gender_accuracy: 0.7662 - age_mse: 771.1946 - val_loss: 55.3710 - val_gender_loss: 0.4799 - val_age_loss: 41.5023 - val_gender_accuracy: 0.7830 - val_age_mse: 501.5604 - lr: 0.0010
# Epoch 13/30
# 223/223 [==============================] - ETA: 0s - loss: 70.8778 - gender_loss: 0.4889 - age_loss: 56.8265 - gender_accuracy: 0.7828 - age_mse: 724.8486WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 13: saving model to model_checkpoints/
# 223/223 [==============================] - 328s 1s/step - loss: 70.8778 - gender_loss: 0.4889 - age_loss: 56.8265 - gender_accuracy: 0.7828 - age_mse: 724.8486 - val_loss: 58.7413 - val_gender_loss: 0.6031 - val_age_loss: 42.8788 - val_gender_accuracy: 0.7006 - val_age_mse: 276.7081 - lr: 0.0010
# Epoch 14/30
# 223/223 [==============================] - ETA: 0s - loss: 68.0390 - gender_loss: 0.4896 - age_loss: 54.9210 - gender_accuracy: 0.7825 - age_mse: 665.2568WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 14: saving model to model_checkpoints/
# 223/223 [==============================] - 321s 1s/step - loss: 68.0390 - gender_loss: 0.4896 - age_loss: 54.9210 - gender_accuracy: 0.7825 - age_mse: 665.2568 - val_loss: 51.5679 - val_gender_loss: 0.4781 - val_age_loss: 39.1852 - val_gender_accuracy: 0.7778 - val_age_mse: 392.4879 - lr: 0.0010
# Epoch 15/30
# 223/223 [==============================] - ETA: 0s - loss: 66.4366 - gender_loss: 0.4802 - age_loss: 53.8265 - gender_accuracy: 0.7856 - age_mse: 622.4962WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 15: saving model to model_checkpoints/
# 223/223 [==============================] - 319s 1s/step - loss: 66.4366 - gender_loss: 0.4802 - age_loss: 53.8265 - gender_accuracy: 0.7856 - age_mse: 622.4962 - val_loss: 61.5511 - val_gender_loss: 0.4429 - val_age_loss: 48.2862 - val_gender_accuracy: 0.8020 - val_age_mse: 397.0077 - lr: 0.0010
# Epoch 16/30
# 223/223 [==============================] - ETA: 0s - loss: 64.9282 - gender_loss: 0.4771 - age_loss: 53.4697 - gender_accuracy: 0.7851 - age_mse: 590.9354WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 16: saving model to model_checkpoints/
# 223/223 [==============================] - 330s 1s/step - loss: 64.9282 - gender_loss: 0.4771 - age_loss: 53.4697 - gender_accuracy: 0.7851 - age_mse: 590.9354 - val_loss: 50.7776 - val_gender_loss: 0.4873 - val_age_loss: 38.9107 - val_gender_accuracy: 0.7647 - val_age_mse: 215.1894 - lr: 0.0010
# Epoch 17/30
# 223/223 [==============================] - ETA: 0s - loss: 63.1114 - gender_loss: 0.4640 - age_loss: 52.0083 - gender_accuracy: 0.7929 - age_mse: 552.6953WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 17: saving model to model_checkpoints/
# 223/223 [==============================] - 322s 1s/step - loss: 63.1114 - gender_loss: 0.4640 - age_loss: 52.0083 - gender_accuracy: 0.7929 - age_mse: 552.6953 - val_loss: 60.3049 - val_gender_loss: 0.4390 - val_age_loss: 49.2283 - val_gender_accuracy: 0.8046 - val_age_mse: 525.8256 - lr: 0.0010
# Epoch 18/30
# 223/223 [==============================] - ETA: 0s - loss: 61.7173 - gender_loss: 0.4570 - age_loss: 51.6505 - gender_accuracy: 0.8012 - age_mse: 537.9619WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 18: saving model to model_checkpoints/
# 223/223 [==============================] - 322s 1s/step - loss: 61.7173 - gender_loss: 0.4570 - age_loss: 51.6505 - gender_accuracy: 0.8012 - age_mse: 537.9619 - val_loss: 53.6363 - val_gender_loss: 0.3960 - val_age_loss: 43.4895 - val_gender_accuracy: 0.8250 - val_age_mse: 425.3195 - lr: 0.0010
# Epoch 19/30
# 223/223 [==============================] - ETA: 0s - loss: 62.0825 - gender_loss: 0.4522 - age_loss: 51.6885 - gender_accuracy: 0.8015 - age_mse: 531.2058WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 19: saving model to model_checkpoints/
# 223/223 [==============================] - 319s 1s/step - loss: 62.0825 - gender_loss: 0.4522 - age_loss: 51.6885 - gender_accuracy: 0.8015 - age_mse: 531.2058 - val_loss: 56.8457 - val_gender_loss: 0.3986 - val_age_loss: 47.2438 - val_gender_accuracy: 0.8115 - val_age_mse: 457.8729 - lr: 0.0010
# Epoch 20/30
# 223/223 [==============================] - ETA: 0s - loss: 60.4791 - gender_loss: 0.4559 - age_loss: 51.0076 - gender_accuracy: 0.8008 - age_mse: 512.7199WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 20: saving model to model_checkpoints/
# 223/223 [==============================] - 318s 1s/step - loss: 60.4791 - gender_loss: 0.4559 - age_loss: 51.0076 - gender_accuracy: 0.8008 - age_mse: 512.7199 - val_loss: 45.8543 - val_gender_loss: 0.4582 - val_age_loss: 36.8426 - val_gender_accuracy: 0.7852 - val_age_mse: 286.1044 - lr: 0.0010
# Epoch 21/30
# 223/223 [==============================] - ETA: 0s - loss: 60.2780 - gender_loss: 0.4428 - age_loss: 51.3102 - gender_accuracy: 0.8058 - age_mse: 503.4897WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 21: saving model to model_checkpoints/
# 223/223 [==============================] - 316s 1s/step - loss: 60.2780 - gender_loss: 0.4428 - age_loss: 51.3102 - gender_accuracy: 0.8058 - age_mse: 503.4897 - val_loss: 46.4384 - val_gender_loss: 0.4340 - val_age_loss: 37.4676 - val_gender_accuracy: 0.7575 - val_age_mse: 338.0731 - lr: 0.0010
# Epoch 22/30
# 223/223 [==============================] - ETA: 0s - loss: 59.4612 - gender_loss: 0.4354 - age_loss: 50.6570 - gender_accuracy: 0.8128 - age_mse: 489.2538WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 22: saving model to model_checkpoints/
# 223/223 [==============================] - 317s 1s/step - loss: 59.4612 - gender_loss: 0.4354 - age_loss: 50.6570 - gender_accuracy: 0.8128 - age_mse: 489.2538 - val_loss: 44.7860 - val_gender_loss: 0.4519 - val_age_loss: 36.4808 - val_gender_accuracy: 0.7721 - val_age_mse: 328.7012 - lr: 0.0010
# Epoch 23/30
# 223/223 [==============================] - ETA: 0s - loss: 59.6142 - gender_loss: 0.4489 - age_loss: 50.6171 - gender_accuracy: 0.7995 - age_mse: 495.4886WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 23: saving model to model_checkpoints/
# 223/223 [==============================] - 315s 1s/step - loss: 59.6142 - gender_loss: 0.4489 - age_loss: 50.6171 - gender_accuracy: 0.7995 - age_mse: 495.4886 - val_loss: 53.8065 - val_gender_loss: 0.4300 - val_age_loss: 45.1595 - val_gender_accuracy: 0.8020 - val_age_mse: 482.2454 - lr: 0.0010
# Epoch 24/30
# 223/223 [==============================] - ETA: 0s - loss: 60.3750 - gender_loss: 0.4464 - age_loss: 50.8911 - gender_accuracy: 0.8016 - age_mse: 490.6134WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 24: saving model to model_checkpoints/
# 223/223 [==============================] - 320s 1s/step - loss: 60.3750 - gender_loss: 0.4464 - age_loss: 50.8911 - gender_accuracy: 0.8016 - age_mse: 490.6134 - val_loss: 56.4630 - val_gender_loss: 0.3545 - val_age_loss: 45.2025 - val_gender_accuracy: 0.8391 - val_age_mse: 432.8138 - lr: 0.0010
# Epoch 25/30
# 223/223 [==============================] - ETA: 0s - loss: 59.2774 - gender_loss: 0.4330 - age_loss: 49.8555 - gender_accuracy: 0.8105 - age_mse: 482.1116WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 25: saving model to model_checkpoints/
# 223/223 [==============================] - 316s 1s/step - loss: 59.2774 - gender_loss: 0.4330 - age_loss: 49.8555 - gender_accuracy: 0.8105 - age_mse: 482.1116 - val_loss: 44.1941 - val_gender_loss: 0.3968 - val_age_loss: 35.8469 - val_gender_accuracy: 0.8176 - val_age_mse: 350.2890 - lr: 0.0010
# Epoch 26/30
# 223/223 [==============================] - ETA: 0s - loss: 58.1668 - gender_loss: 0.4350 - age_loss: 49.8806 - gender_accuracy: 0.8110 - age_mse: 476.2500WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 26: saving model to model_checkpoints/
# 223/223 [==============================] - 316s 1s/step - loss: 58.1668 - gender_loss: 0.4350 - age_loss: 49.8806 - gender_accuracy: 0.8110 - age_mse: 476.2500 - val_loss: 43.8863 - val_gender_loss: 0.3723 - val_age_loss: 35.9909 - val_gender_accuracy: 0.8360 - val_age_mse: 293.2071 - lr: 0.0010
# Epoch 27/30
# 223/223 [==============================] - ETA: 0s - loss: 56.9907 - gender_loss: 0.4304 - age_loss: 49.1162 - gender_accuracy: 0.8149 - age_mse: 472.0157WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 27: saving model to model_checkpoints/
# 223/223 [==============================] - 317s 1s/step - loss: 56.9907 - gender_loss: 0.4304 - age_loss: 49.1162 - gender_accuracy: 0.8149 - age_mse: 472.0157 - val_loss: 45.4696 - val_gender_loss: 0.3809 - val_age_loss: 37.7806 - val_gender_accuracy: 0.8343 - val_age_mse: 296.1537 - lr: 0.0010
# Epoch 28/30
# 223/223 [==============================] - ETA: 0s - loss: 56.0622 - gender_loss: 0.4262 - age_loss: 48.4544 - gender_accuracy: 0.8174 - age_mse: 451.2227WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 28: saving model to model_checkpoints/
# 223/223 [==============================] - 322s 1s/step - loss: 56.0622 - gender_loss: 0.4262 - age_loss: 48.4544 - gender_accuracy: 0.8174 - age_mse: 451.2227 - val_loss: 43.0483 - val_gender_loss: 0.4346 - val_age_loss: 35.4774 - val_gender_accuracy: 0.8151 - val_age_mse: 283.5329 - lr: 0.0010
# Epoch 29/30
# 223/223 [==============================] - ETA: 0s - loss: 55.7421 - gender_loss: 0.4248 - age_loss: 48.2395 - gender_accuracy: 0.8157 - age_mse: 453.0311WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 29: saving model to model_checkpoints/
# 223/223 [==============================] - 314s 1s/step - loss: 55.7421 - gender_loss: 0.4248 - age_loss: 48.2395 - gender_accuracy: 0.8157 - age_mse: 453.0311 - val_loss: 45.9533 - val_gender_loss: 0.3877 - val_age_loss: 38.6548 - val_gender_accuracy: 0.8385 - val_age_mse: 355.9852 - lr: 0.0010
# Epoch 30/30
# 223/223 [==============================] - ETA: 0s - loss: 58.1108 - gender_loss: 0.4270 - age_loss: 48.9246 - gender_accuracy: 0.8173 - age_mse: 468.0880WARNING:tensorflow:Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,gender_loss,age_loss,gender_accuracy,age_mse,val_loss,val_gender_loss,val_age_loss,val_gender_accuracy,val_age_mse
#
# Epoch 30: saving model to model_checkpoints/
# 223/223 [==============================] - 315s 1s/step - loss: 58.1108 - gender_loss: 0.4270 - age_loss: 48.9246 - gender_accuracy: 0.8173 - age_mse: 468.0880 - val_loss: 46.4978 - val_gender_loss: 0.3709 - val_age_loss: 36.9860 - val_gender_accuracy: 0.8374 - val_age_mse: 272.2262 - lr: 0.0010

# %%
model.save("age_gender.h5")

# %%
plt.plot(hist.history["loss"])
plt.plot(hist.history["val_loss"])
plt.title("Training Progress")
plt.ylabel("Gender Accuracy/Loss")
plt.xlabel("Epochs")
plt.legend(["total loss", "total val_loss"], loc="upper left")
plt.show()

# %%
plt.plot(hist.history["gender_accuracy"])
plt.plot(hist.history["val_gender_accuracy"])
plt.title("Training Progress")
plt.ylabel("Gender Accuracy/Loss")
plt.xlabel("Epochs")
plt.legend(["gender_accuracy", "val_gender_accuracy"], loc="upper left")
plt.show()

# %%
plt.plot(hist.history["gender_loss"])
plt.plot(hist.history["val_gender_loss"])
plt.title("Training Progress")
plt.ylabel("Gender Accuracy/Loss")
plt.xlabel("Epochs")
plt.legend(["gender_loss", "val_gender_loss"], loc="upper left")
plt.show()

# %%
plt.plot(hist.history["age_mse"])
plt.plot(hist.history["val_age_mse"])
plt.title("Training Progress")
plt.ylabel("Age Accuracy/Loss")
plt.xlabel("Epochs")
plt.legend(["age_mee", "val_age_mse"], loc="upper left")
plt.show()

# %%
plt.plot(hist.history["age_loss"])
plt.plot(hist.history["val_age_loss"])
plt.title("Training Progress")
plt.ylabel("Age/Loss")
plt.xlabel("Epochs")
plt.legend(["age_loss", "val_age_loss"], loc="upper left")
plt.show()

# %%
model.evaluate(test_dataset)
# Out:
# 75/75 [==============================] - 66s 878ms/step - loss: 45.2992 - gender_loss: 0.3688 - age_loss: 35.7833 - gender_accuracy: 0.8414 - age_mse: 277.6516
# [45.299171447753906,
#  0.36881160736083984,
#  35.783287048339844,
#  0.841383695602417,
#  277.651611328125]
